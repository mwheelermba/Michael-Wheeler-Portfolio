# %% [markdown]
# # Threshold Tradeoff Analysis
#
# Static (non-interactive) analysis of the fraud-loss vs. customer-friction tradeoff across rule threshold settings, using the same simulation modules as the Streamlit app.
#
# **Sections:**
# 1. Generate the synthetic transaction population
# 2. Sweep each rule threshold across its range
# 3. Plot fraud blocked vs. legitimate declined curves
# 4. Net loss impact surface and suggested operating points

# %%
import sys
sys.path.append("..")

import numpy as np
import pandas as pd

from app.simulator import SimulationConfig, generate_population
from app.rules import RuleConfig, apply_rules
from app.scoring import ScoreConfig, compute_risk_scores
from app.metrics import FrictionAssumptions, compute_metrics

# %% [markdown]
# ## 1. Generate population

# %%
# TODO: generate the population and inspect signal distributions by fraud label
# df = generate_population(SimulationConfig())
# df.groupby("is_fraud").describe()

# %% [markdown]
# ## 2. Threshold sweeps

# %%
# TODO: for each rule, sweep its threshold across the slider range while
# holding the others at defaults; collect MetricResults per setting.

# %% [markdown]
# ## 3. Tradeoff curves

# %%
# TODO: plot fraud blocked ($) vs. legitimate declined ($) per threshold
# to visualize the loss-friction frontier for each rule.

# %% [markdown]
# ## 4. Net loss impact and operating point

# %%
# TODO: identify the threshold setting minimizing net loss impact under
# the default friction assumptions, and check it against the alert budget.
